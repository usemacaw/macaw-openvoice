# %% [markdown]
# # Macaw OpenVoice — CLI Validation Notebook
#
# Validates **all CLI commands** of Macaw OpenVoice.
# Run all cells sequentially on Google Colab (GPU runtime recommended).
#
# **What this validates:**
# - Package installation (end-user experience)
# - Model management: `catalog`, `pull`, `list`, `inspect`, `remove`
# - Server management: `serve`, `ps`
# - Transcription: all output formats, language, ITN control, hot words, streaming
# - Translation: audio-to-English
#
# > **Pre-requisite:** Select a GPU runtime (Runtime > Change runtime type > T4 GPU)

# %% [markdown]
# ## 1. Configuration

# %%
# Edit these before running
STT_MODEL = 'faster-whisper-tiny'
TTS_MODEL = 'kokoro-v1'
SERVER_PORT = 8000
BASE_URL = f'http://localhost:{SERVER_PORT}'

# Installation source:
#   'pip'     — install released version from PyPI
#   'develop' — install from git develop branch (pre-release validation)
INSTALL_FROM = 'develop'

# %% [markdown]
# ## 2. Installation
#
# Installs from **PyPI** or **git develop branch** based on `INSTALL_FROM` above.
#
# > **Note (Colab):** You may see a pip resolver warning about `protobuf` conflicts with pre-installed `tensorflow`/`grpcio-status`. This is harmless — Macaw requires `protobuf>=6.31` and does not use TensorFlow. The warning can be safely ignored.

# %%
# %%capture
if INSTALL_FROM == 'develop':
    # !pip install 'macaw-openvoice[faster-whisper,kokoro] @ git+https://github.com/usemacaw/macaw-openvoice.git@develop'
else:
    # !pip install macaw-openvoice[faster-whisper,kokoro]

# %%
# !macaw --version
# Out:
# macaw, version 0.1.7

# %% [markdown]
# ## 3. Model Management

# %% [markdown]
# ### 3.1 `macaw catalog`

# %%
# !macaw catalog
# Out:
# 2026-02-22T20:59:45.104374Z [info     ] catalog_loaded                 component=registry.catalog models_count=11
# NAME                     TYPE   ENGINE            DESCRIPTION
# faster-whisper-large-v3  stt    faster-whisper    Faster Whisper Large V3 — best quality, requires GPU
# faster-whisper-medium    stt    faster-whisper    Faster Whisper Medium — good quality/speed balance
# faster-whisper-small     stt    faster-whisper    Faster Whisper Small — lightweight, good for CPU
# faster-whisper-tiny      stt    faster-whisper    Faster Whisper Tiny — ultra-light, ideal for testing
# distil-whisper-large-v3  stt    faster-whisper    Distil-Whisper Large V3 — 6x faster, ~1% WER gap
# kokoro-v1                tts    kokoro            Kokoro TTS — neural text-to-speech, 82M parameters
# qwen3-tts-1.7b-custom    tts    qwen3-tts         Qwen3-TTS 1.7B CustomVoice — 9 preset voices, 10 languages
# qwen3-tts-0.6b-custom    tts    qwen3-tts         Qwen3-TTS 0.6B CustomVoice — lightweight, 9 preset voices, 10 languages
# qwen3-tts-1.7b-base      tts    qwen3-tts         Qwen3-TTS 1.7B Base — voice cloning from 3-second reference
# qwen3-tts-0.6b-base      tts    qwen3-tts         Qwen3-TTS 0.6B Base — lightweight voice cloning
# qwen3-tts-1.7b-design    tts    qwen3-tts         Qwen3-TTS 1.7B VoiceDesign — custom voice via natural language instruction
#
# Run 'macaw pull <name>' to download a model.

# %% [markdown]
# ### 3.2 `macaw pull`

# %%
# !macaw pull $STT_MODEL
# Out:
# 2026-02-22T20:59:45.916453Z [info     ] catalog_loaded                 component=registry.catalog models_count=11
# Downloading faster-whisper-tiny from Systran/faster-whisper-tiny...
# 2026-02-22T20:59:46.140601Z [info     ] download_starting              component=registry.downloader model=faster-whisper-tiny repo=Systran/faster-whisper-tiny target=/root/.macaw/models/faster-whisper-tiny
# Fetching 6 files:   0% 0/6 [00:00<?, ?it/s]
# config.json: 2.25kB [00:00, 1.60MB/s]
#
# vocabulary.txt: 0.00B [00:00, ?B/s]
#
# README.md: 1.99kB [00:00, 988kB/s][A
#
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
#
# .gitattributes: 1.48kB [00:00, 10.1MB/s]A
# vocabulary.txt: 460kB [00:00, 28.0MB/s]
# tokenizer.json: 2.20MB [00:00, 84.1MB/s]  4.93it/s]
#
# model.bin:   0% 0.00/75.5M [00:00<?, ?B/s]
# model.bin:  11% 8.55M/75.5M [00:00<00:04, 15.6MB/s]
# model.bin: 100% 75.5M/75.5M [00:00<00:00, 92.9MB/s]
# Fetching 6 files: 100% 6/6 [00:01<00:00,  5.44it/s]
# 2026-02-22T20:59:47.400808Z [info     ] download_complete              component=registry.downloader model=faster-whisper-tiny path=/root/.macaw/models/faster-whisper-tiny
# 2026-02-22T20:59:47.404392Z [info     ] manifest_written               component=registry.downloader model=faster-whisper-tiny path=/root/.macaw/models/faster-whisper-tiny/macaw.yaml
# 2026-02-22T20:59:47.412934Z [info     ] manifest_validated             component=registry.downloader model=faster-whisper-tiny
# Model installed in /root/.macaw/models/faster-whisper-tiny
# Run 'macaw serve' to start the server.

# %%
# !macaw pull $TTS_MODEL
# Out:
# 2026-02-22T20:59:48.142924Z [info     ] catalog_loaded                 component=registry.catalog models_count=11
# Downloading kokoro-v1 from hexgrad/Kokoro-82M...
# 2026-02-22T20:59:48.349453Z [info     ] download_starting              component=registry.downloader model=kokoro-v1 repo=hexgrad/Kokoro-82M target=/root/.macaw/models/kokoro-v1
# Fetching 72 files:   0% 0/72 [00:00<?, ?it/s]
# config.json: 2.35kB [00:00, 9.52MB/s]
#
# VOICES.md: 7.62kB [00:00, 3.89MB/s]
#
# README.md: 6.35kB [00:00, 20.4MB/s]
#
# DONATE.md: 2.56kB [00:00, 18.3MB/s]
#
# .gitattributes: 1.91kB [00:00, 15.2MB/s]
# Fetching 72 files:   1% 1/72 [00:00<00:13,  5.27it/s]
# EVAL.md: 100% 534/534 [00:00<00:00, 5.42MB/s]
#
# SAMPLES.md: 5.96kB [00:00, 31.4MB/s]
#
# eval/ArtificialAnalysis-2025-02-26.jpeg:   0% 0.00/940k [00:00<?, ?B/s]
#
# HEARME.wav:   0% 0.00/996k [00:00<?, ?B/s]
#
#
# af_heart_0.wav: 100% 238k/238k [00:00<00:00, 21.7MB/s]A
# HEARME.wav: 100% 996k/996k [00:00<00:00, 41.3MB/s]
#
#
# af_heart_1.wav: 100% 517k/517k [00:00<00:00, 25.4MB/s]
#
#
# af_heart_2.wav:   0% 0.00/497k [00:00<?, ?B/s]
#
#
# af_heart_2.wav: 100% 497k/497k [00:00<00:00, 28.3MB/s]?, ?B/s]
#
#
# kokoro-v1_0.pth:   0% 0.00/327M [00:00<?, ?B/s]
#
#
#
# eval/TTS_Spaces_Arena-2025-02-26.jpeg:   0% 0.00/515k [00:00<?, ?B/s]
#
#
#
#
# samples/af_heart_3.wav:   0% 0.00/1.41M [00:00<?, ?B/s]
#
#
#
#
#
# samples/af_heart_4.wav:   0% 0.00/1.12M [00:00<?, ?B/s]
#
#
#
#
#
#
# samples/af_heart_5.wav:   0% 0.00/1.03M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# voices/af_alloy.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# eval/TTS_Arena-2025-02-26.jpeg: 100% 560k/560k [00:00<00:00, 1.11MB/s]
#
# eval/ArtificialAnalysis-2025-02-26.jpeg: 100% 940k/940k [00:00<00:00, 1.48MB/s]
# Fetching 72 files:  11% 8/72 [00:00<00:06,  9.26it/s]
#
#
#
#
#
# samples/af_heart_4.wav: 100% 1.12M/1.12M [00:00<00:00, 2.64MB/s]
#
#
#
#
#
#
#
# samples/af_heart_5.wav: 100% 1.03M/1.03M [00:00<00:00, 2.47MB/s]
#
#
#
#
#
#
#
#
# voices/af_alloy.pt: 100% 523k/523k [00:00<00:00, 1.26MB/s]
#
#
#
#
#
# samples/af_heart_3.wav: 100% 1.41M/1.41M [00:00<00:00, 2.90MB/s]
#
#
#
#
# eval/TTS_Spaces_Arena-2025-02-26.jpeg: 100% 515k/515k [00:00<00:00, 813kB/s]
# Fetching 72 files:  14% 10/72 [00:01<00:06,  9.87it/s]
# voices/af_aoede.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/af_bella.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/af_heart.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/af_jessica.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/af_kore.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/af_nicole.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# voices/af_nova.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/af_bella.pt: 100% 523k/523k [00:00<00:00, 2.09MB/s]
#
# voices/af_aoede.pt: 100% 523k/523k [00:00<00:00, 1.92MB/s]
#
#
#
#
#
# voices/af_jessica.pt: 100% 523k/523k [00:00<00:00, 2.15MB/s]
#
#
#
#
# voices/af_heart.pt: 100% 523k/523k [00:00<00:00, 2.04MB/s]
#
#
#
#
#
#
# voices/af_kore.pt: 100% 523k/523k [00:00<00:00, 2.12MB/s]
#
#
#
#
#
#
#
# voices/af_nicole.pt: 100% 523k/523k [00:00<00:00, 2.16MB/s]
#
#
#
#
#
#
#
#
# voices/af_nova.pt: 100% 523k/523k [00:00<00:00, 2.22MB/s]
#
# voices/af_river.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/af_sarah.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/af_sky.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/am_adam.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/am_echo.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/am_eric.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# kokoro-v1_0.pth:  20% 67.0M/327M [00:01<00:05, 51.6MB/s]
#
#
#
#
#
#
#
# voices/am_fenrir.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# kokoro-v1_0.pth:  41% 134M/327M [00:01<00:01, 107MB/s]
#
#
# voices/af_sarah.pt: 100% 523k/523k [00:00<00:00, 2.01MB/s]
#
# voices/af_river.pt: 100% 523k/523k [00:00<00:00, 1.81MB/s]
#
#
# kokoro-v1_0.pth:  59% 193M/327M [00:01<00:00, 163MB/s]
#
#
#
# voices/af_sky.pt: 100% 523k/523k [00:00<00:00, 1.68MB/s]
#
#
#
#
#
# voices/am_adam.pt: 100% 523k/523k [00:00<00:00, 1.76MB/s]
#
#
#
#
#
# voices/am_adam.pt: 100% 523k/523k [00:00<00:00, 1.73MB/s]
#
#
#
#
#
#
#
#
# voices/am_echo.pt: 100% 523k/523k [00:00<00:00, 1.72MB/s]s]
# voices/am_fenrir.pt: 100% 523k/523k [00:00<00:00, 1.87MB/s]
#
#
#
#
#
#
#
# voices/am_eric.pt: 100% 523k/523k [00:00<00:00, 1.58MB/s]
#
# voices/am_liam.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/am_michael.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/am_onyx.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/am_puck.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/bf_alice.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/am_santa.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# kokoro-v1_0.pth:  79% 260M/327M [00:01<00:00, 187MB/s]
#
#
#
#
#
#
#
# voices/bf_emma.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/am_puck.pt: 100% 523k/523k [00:00<00:00, 2.17MB/s]
#
#
#
#
#
#
# voices/bf_alice.pt: 100% 523k/523k [00:00<00:00, 2.24MB/s]
#
#
#
#
#
#
#
# voices/am_santa.pt: 100% 523k/523k [00:00<00:00, 2.17MB/s]
#
#
#
#
# voices/am_onyx.pt: 100% 523k/523k [00:00<00:00, 1.90MB/s]
#
#
#
#
#
#
#
#
# voices/bf_emma.pt: 100% 523k/523k [00:00<00:00, 2.22MB/s]
# voices/bf_emma.pt: 100% 523k/523k [00:00<00:00, 2.21MB/s]
#
#
#
# voices/am_liam.pt: 100% 523k/523k [00:00<00:00, 1.34MB/s]/s]
# voices/am_michael.pt: 100% 523k/523k [00:00<00:00, 1.36MB/s]
#
#
# kokoro-v1_0.pth: 100% 327M/327M [00:02<00:00, 155MB/s]
# Fetching 72 files:  15% 11/72 [00:02<00:19,  3.11it/s]
# voices/bm_daniel.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# voices/bm_fable.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/bf_lily.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/ef_dora.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/bm_george.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/bf_isabella.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/bm_lewis.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# voices/em_alex.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/bf_lily.pt: 100% 523k/523k [00:00<00:00, 2.57MB/s]
#
# voices/bm_daniel.pt: 100% 523k/523k [00:00<00:00, 2.25MB/s]
#
#
#
#
#
#
# voices/bf_isabella.pt: 100% 523k/523k [00:00<00:00, 2.50MB/s]
# Fetching 72 files:  57% 41/72 [00:02<00:01, 19.21it/s]
#
# voices/bm_fable.pt: 100% 523k/523k [00:00<00:00, 2.27MB/s]
#
#
#
#
#
#
#
# voices/bm_lewis.pt: 100% 523k/523k [00:00<00:00, 2.42MB/s]
#
#
#
#
# voices/ef_dora.pt: 100% 523k/523k [00:00<00:00, 2.22MB/s]
#
#
#
#
#
# voices/bm_george.pt: 100% 523k/523k [00:00<00:00, 2.22MB/s]
#
#
#
#
#
#
#
#
# voices/em_alex.pt: 100% 523k/523k [00:00<00:00, 2.20MB/s]
#
# voices/em_santa.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# voices/ff_siwis.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/hf_beta.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/hf_alpha.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/hm_omega.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/if_sara.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/hm_psi.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# voices/im_nicola.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/hf_beta.pt: 100% 523k/523k [00:00<00:00, 2.54MB/s]
#
# voices/em_santa.pt: 100% 523k/523k [00:00<00:00, 2.27MB/s]
# Fetching 72 files:  68% 49/72 [00:03<00:01, 19.14it/s]
#
# voices/ff_siwis.pt: 100% 523k/523k [00:00<00:00, 2.29MB/s]
#
#
#
#
#
# voices/hm_omega.pt: 100% 523k/523k [00:00<00:00, 2.50MB/s]
#
#
#
#
#
#
# voices/if_sara.pt: 100% 523k/523k [00:00<00:00, 2.58MB/s]
#
#
#
#
#
#
#
# voices/hm_psi.pt: 100% 523k/523k [00:00<00:00, 2.52MB/s]
#
#
#
#
#
#
#
#
# voices/im_nicola.pt: 100% 523k/523k [00:00<00:00, 2.54MB/s]
#
#
#
#
# voices/hf_alpha.pt: 100% 523k/523k [00:00<00:00, 1.93MB/s]
#
# voices/jf_alpha.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# voices/jf_gongitsune.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/jf_nezumi.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/jm_kumo.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/jf_tebukuro.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/pm_alex.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/pf_dora.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# voices/pm_santa.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/jf_nezumi.pt: 100% 523k/523k [00:00<00:00, 2.58MB/s]
#
# voices/jf_alpha.pt: 100% 523k/523k [00:00<00:00, 2.31MB/s]
# Fetching 72 files:  79% 57/72 [00:03<00:00, 18.97it/s]
#
# voices/jf_gongitsune.pt: 100% 523k/523k [00:00<00:00, 2.26MB/s]
#
#
#
#
#
#
# voices/pm_alex.pt: 100% 523k/523k [00:00<00:00, 2.47MB/s]
#
#
#
#
#
#
#
# voices/pf_dora.pt: 100% 523k/523k [00:00<00:00, 2.43MB/s]
#
#
#
#
#
# voices/jf_tebukuro.pt: 100% 523k/523k [00:00<00:00, 2.11MB/s]
#
#
#
#
# voices/jm_kumo.pt: 100% 523k/523k [00:00<00:00, 2.02MB/s]
#
#
#
#
#
#
#
#
# voices/pm_santa.pt: 100% 523k/523k [00:00<00:00, 2.06MB/s]
#
# voices/zf_xiaobei.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
# voices/zf_xiaoni.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
# voices/zf_xiaoyi.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
# voices/zf_xiaoxiao.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
# voices/zm_yunjian.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
# voices/zm_yunxi.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
# voices/zm_yunxia.pt:   0% 0.00/523k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# voices/zm_yunyang.pt:   0% 0.00/523k [00:00<?, ?B/s]
# voices/zf_xiaobei.pt: 100% 523k/523k [00:00<00:00, 2.26MB/s]
# Fetching 72 files:  90% 65/72 [00:04<00:00, 18.88it/s]
#
#
#
# voices/zf_xiaoxiao.pt: 100% 523k/523k [00:00<00:00, 2.34MB/s]
#
#
# voices/zf_xiaoni.pt: 100% 523k/523k [00:00<00:00, 2.21MB/s]
#
#
#
# voices/zf_xiaoyi.pt: 100% 523k/523k [00:00<00:00, 2.26MB/s]
#
#
#
#
#
# voices/zm_yunjian.pt: 100% 523k/523k [00:00<00:00, 2.26MB/s]
#
#
#
#
#
#
# voices/zm_yunxi.pt: 100% 523k/523k [00:00<00:00, 2.28MB/s]
#
#
#
#
#
#
#
# voices/zm_yunxia.pt: 100% 523k/523k [00:00<00:00, 2.10MB/s]
#
#
#
#
#
#
#
#
# voices/zm_yunyang.pt: 100% 523k/523k [00:00<00:00, 2.43MB/s]
# Fetching 72 files: 100% 72/72 [00:04<00:00, 16.78it/s]
# 2026-02-22T20:59:52.777583Z [info     ] download_complete              component=registry.downloader model=kokoro-v1 path=/root/.macaw/models/kokoro-v1
# 2026-02-22T20:59:52.779774Z [info     ] manifest_written               component=registry.downloader model=kokoro-v1 path=/root/.macaw/models/kokoro-v1/macaw.yaml
# 2026-02-22T20:59:52.782494Z [info     ] manifest_validated             component=registry.downloader model=kokoro-v1
# Model installed in /root/.macaw/models/kokoro-v1
# Run 'macaw serve' to start the server.

# %% [markdown]
# ### 3.3 `macaw list`

# %%
# !macaw list
# Out:
# 2026-02-22T20:59:53.598203Z [info     ] model_found                    component=registry engine=faster-whisper name=faster-whisper-tiny
# 2026-02-22T20:59:53.599869Z [info     ] model_found                    component=registry engine=kokoro name=kokoro-v1
# NAME                 TYPE   ENGINE            ARCHITECTURE        MEMORY
# faster-whisper-tiny  stt    faster-whisper    encoder-decoder     256 MB
# kokoro-v1            tts    kokoro            —                   512 MB

# %% [markdown]
# ### 3.4 `macaw inspect`

# %%
# !macaw inspect $STT_MODEL
# Out:
# 2026-02-22T20:59:54.242072Z [info     ] model_found                    component=registry engine=faster-whisper name=faster-whisper-tiny
# 2026-02-22T20:59:54.243685Z [info     ] model_found                    component=registry engine=kokoro name=kokoro-v1
# Name:            faster-whisper-tiny
# Type:            stt
# Engine:          faster-whisper
# Version:         3.0.0
# Architecture:    encoder-decoder
# Languages:       auto, en, pt, es, ja, zh
# Memory:          256 MB
# GPU Required:    No
# GPU Recommended: No
# Capabilities:    streaming, word_timestamps, translation, batch_inference, language_detection
# Description:     Faster Whisper Tiny - encoder-decoder STT

# %%
# !macaw inspect $TTS_MODEL
# Out:
# 2026-02-22T20:59:54.885037Z [info     ] model_found                    component=registry engine=faster-whisper name=faster-whisper-tiny
# 2026-02-22T20:59:54.886745Z [info     ] model_found                    component=registry engine=kokoro name=kokoro-v1
# Name:            kokoro-v1
# Type:            tts
# Engine:          kokoro
# Version:         1.0.0
# Architecture:    —
# Languages:       en, es, fr, hi, it, ja, pt, zh
# Memory:          512 MB
# GPU Required:    No
# GPU Recommended: Yes
# Capabilities:    streaming
# Description:     Kokoro TTS - neural text-to-speech

# %% [markdown]
# ## 4. Server Management

# %% [markdown]
# ### 4.1 Start server in background

# %%
import os
os.environ['MACAW_WORKER_HEALTH_PROBE_TIMEOUT_S'] = '300'
os.environ['MACAW_LOG_FORMAT'] = 'json'  # avoid ANSI escape codes in logs
os.environ['MACAW_VOICE_DIR'] = '/tmp/macaw_voices'

# %%
# !nohup macaw serve --host 0.0.0.0 --port $SERVER_PORT --voice-dir /tmp/macaw_voices > /tmp/macaw.log 2>&1 &

# %%
# %cat /tmp/macaw.log

# %%
import time, httpx

print('Waiting for server ...')
for i in range(90):
    try:
        r = httpx.get(f'{BASE_URL}/health', timeout=5)
        if r.json().get('status') == 'ok':
            print(f'Server ready! (attempt {i+1})')
            print(r.json())
            assert r.json().get('workers_ready', 0) >= 2, 'Workers not ready'
            break
    except Exception:
        pass
    time.sleep(2)
else:
    print('Server did not start. Logs:')
    # !tail -50 /tmp/macaw.log
    raise RuntimeError('Server not ready')
# Out:
# Waiting for server ...
# Server ready! (attempt 20)
# {'status': 'ok', 'version': '0.1.7', 'models_loaded': 2, 'workers_ready': 2, 'workers_total': 2}

# %% [markdown]
# ### 4.2 `macaw ps`

# %%
# !macaw ps --server $BASE_URL
# Out:
# {"event": "HTTP Request: GET http://localhost:8000/v1/models \"HTTP/1.1 200 OK\""}
# NAME                 TYPE   ENGINE
# faster-whisper-tiny  stt    faster-whisper
# kokoro-v1            tts    kokoro

# %% [markdown]
# ## 5. Generate Test Audio
#
# Uses TTS to generate speech, then uses that audio for STT testing (round-trip).

# %%
import httpx

TEST_TEXT = 'The 3 scientists discovered 42 new species in the Amazon rainforest last year.'
r = httpx.post(
    f'{BASE_URL}/v1/audio/speech',
    json={'model': TTS_MODEL, 'input': TEST_TEXT, 'voice': 'default'},
    timeout=120,
)
assert r.status_code == 200, f'TTS failed: {r.status_code} {r.text}'

with open('/tmp/test_audio.wav', 'wb') as f:
    f.write(r.content)
print(f'Test audio saved: {len(r.content):,} bytes')
# Out:
# Test audio saved: 292,844 bytes

# %% [markdown]
# ## 6. Transcription Tests

# %% [markdown]
# ### 6.1 JSON format (default)

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --format json --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ### 6.2 Text format

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --format text --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ### 6.3 Verbose JSON format

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --format verbose_json --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# {
#   "task": "transcribe",
#   "language": "en",
#   "duration": 6.101375102996826,
#   "text": "The three scientists discovered 42 new species in the Amazon rainforest last year.",
#   "segments": [
#     {
#       "id": 0,
#       "start": 0.0,
#       "end": 5.679999828338623,
#       "text": "The three scientists discovered 42 new species in the Amazon rainforest last year.",
#       "avg_logprob": -0.4000459611415863,
#       "compression_ratio": 1.0123456716537476,
#       "no_speech_prob": 0.025115966796875
#     }
#   ]
# }

# %% [markdown]
# ### 6.4 SRT subtitle format

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --format srt --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# 1
# 00:00:00,000 --> 00:00:05,680
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ### 6.5 VTT subtitle format

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --format vtt --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# WEBVTT
#
# 00:00:00.000 --> 00:00:05.680
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ### 6.6 With explicit language

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --language en --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ### 6.7 With ITN disabled
#
# With `--no-itn`, numbers like "3" and "42" should appear as digits (no inverse text normalization).
# Compare with the default output above where ITN may expand them to words.

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --no-itn --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/transcriptions \"HTTP/1.1 200 OK\""}
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ### 6.8 With hot words

# %%
# !macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --hot-words "Macaw,OpenVoice" --server $BASE_URL

# %% [markdown]
# ### 6.9 Streaming transcription
#
# Uses `--stream` flag for WebSocket-based streaming transcription.
# Wrapped in `timeout` to prevent indefinite hangs in notebook execution.

# %%
# !timeout 15 macaw transcribe /tmp/test_audio.wav -m $STT_MODEL --stream --server $BASE_URL || true

# %% [markdown]
# ## 7. Translation

# %%
# !macaw translate /tmp/test_audio.wav -m $STT_MODEL --server $BASE_URL
# Out:
# {"event": "HTTP Request: POST http://localhost:8000/v1/audio/translations \"HTTP/1.1 200 OK\""}
# The three scientists discovered 42 new species in the Amazon rainforest last year.

# %% [markdown]
# ## 8. Cleanup

# %%
import subprocess
subprocess.run(['pkill', '-f', 'macaw serve'],
               stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
print('Server stopped.')
# Out:
# Server stopped.

# %%
# !macaw remove $STT_MODEL --yes
# Out:
# {"component": "registry.downloader", "model": "faster-whisper-tiny", "path": "/root/.macaw/models/faster-whisper-tiny", "event": "model_removed", "level": "info", "timestamp": "2026-02-22T21:00:48.900141Z"}
# Model 'faster-whisper-tiny' removed.

# %%
# !macaw remove $TTS_MODEL --yes
# Out:
# {"component": "registry.downloader", "model": "kokoro-v1", "path": "/root/.macaw/models/kokoro-v1", "event": "model_removed", "level": "info", "timestamp": "2026-02-22T21:00:49.901038Z"}
# Model 'kokoro-v1' removed.

# %%
# !macaw list
# Out:
# No models installed.
# Models directory: /root/.macaw/models
